# %%
Задание 1

# %%
import datetime
from math import*
num = float(input('Введите число большее или равное 0: '))
if num >= 0:
    print(f"корень числа равен: {num**0.5}")
else:
    print("Корень числа не определён!")
time = datetime.datetime.now()
print(time)
# Out:
# Введите число большее или равное 0: 36
# корень числа равен: 6.0
# 2024-10-26 19:37:14.012637

# %% [markdown]
# Задание 2

# %%
from drive.MyDrive.my__module import*
print(func_summ(5, 6))
print(func_summ(8, 8))
print(func_summ(-7, -9))
# Out:
# 11
# 16
# -16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Задание 3

# %%
from drive.MyDrive.Package import*
pif.func_pif(3, 4)
cleanstr.clean_string("ВВИТ    4 Лаба")
# Out:
# Гипотенуза равна: 5.0
# 'ВВИТ 4 Лаба'
