# %% [markdown]
# Задание 1

# %%
def greet(name):
  print(f'Приветствуем {name}')
greet('МТУСИ')
# Out:
# Приветствуем МТУСИ

# %% [markdown]
# Задание 2

# %%
def square(number):
  return(number**2)
print(square(5))
# Out:
# 25

# %% [markdown]
# Задание 3

# %%
def max_of_two(num1, num2):
  if num1==num2:
    print('числа равны')
  else:
    print(max(num1, num2))
max_of_two(7, 6)
max_of_two(8, 8)
# Out:
# 7
# числа равны

# %% [markdown]
# Задание 4

# %%
def describe_person(name, age=30):
  print(f'Имя: {name} , Возраст: {age} лет')
describe_person("Артём")
# Out:
# Имя: Артём , Возраст: 30 лет

# %% [markdown]
# Задание 5

# %%
def is_prime(x):
  if x <= 1: return False
  a = set()
  for i in range(2, int(x**0.5)+1):
    if x%i==0:
      a.add(i)
      a.add(x//i)
  return len(a)==0

print(is_prime(3))
# Out:
# True
