# %% [markdown]
# Задание 1

# %%
class UserAccount:
    def __init__(self, username, email, password):
        self.username = username
        self.email = email
        self.__password = password
    def set_password(self, new_password):
        self.__password = new_password
    def check_password(self, password):
        return self.__password == password

username = input('Ввдите ваше имя: ')
email = input('Введите вашу почту: ')
password = input('Введите пароль: ')

user = UserAccount(username, email, password)

new_password = input('Измените пароль: ')
user.set_password(new_password)

password1 = input('Подтвердите пароль: ')
if user.check_password(password1):
  print("Пароль верный")
else:
  print("Пароль неверный")
# Out:
# Ввдите ваше имя: Артём
# Введите вашу почту: 123@gmail.com
# Введите пароль: 123
# Измените пароль: 456
# Подтвердите пароль: 456
# Пароль верный

# %% [markdown]
# Задание 2

# %%
class Vehicle:
    def __init__(self, make, model):
        self.make = make
        self.model = model
    def get_info(self):
        return f"Марка: {self.make}, Модель: {self.model}"

class Car(Vehicle):
    def __init__(self, make, model, fuel_type):
        super().__init__(make, model)
        self.fuel_type = fuel_type
    def get_info(self):
      info = super().get_info()
      return f"{info}, Топливо: {self.fuel_type}"

car = Vehicle("BMW", "X5 M Competition")
print(car.get_info())
car = Car("BMW", "X5 M Competition", "Бензин")
print(car.get_info())
# Out:
# Марка: BMW, Модель: X5 M Competition
# Марка: BMW, Модель: X5 M Competition, Топливо: Бензин
